# %%
! pip install rembg opencv-python -q

# %%
from rembg import remove
import cv2
from google.colab.patches import cv2_imshow

# %%
input_path = '/content/input.jpg'
output_path = '/content/output.png'

# %%
input = cv2.imread(input_path)
output = remove(input)
cv2.imwrite(output_path, output)
# Out:
# Downloading data from 'https://github.com/danielgatis/rembg/releases/download/v0.0.0/u2net.onnx' to file '/root/.u2net/u2net.onnx'.
# 100%|████████████████████████████████████████| 176M/176M [00:00<00:00, 102GB/s]
# True

# %%
cv2_imshow(input)
# Out:
# <PIL.Image.Image image mode=RGB size=281x179>

# %%
cv2_imshow(output)
# Out:
# <PIL.Image.Image image mode=RGBA size=281x179>
